# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; win64; x64) AppleWebKit/537.63 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
webpage=requests.get("https://www.adyogi.com/connect-with-us?utm_term=Brand_Search&utm_campaign=ADYG_Search_Prospect_India_New&utm_source=ppc&utm_medium=Search&utm_content=India&hsa_acc=6269695156&hsa_cam=10147104471&hsa_grp=121864727666&hsa_ad=693458301313&hsa_src=g&hsa_tgt=kwd-371642833159&hsa_kw=adyogi&hsa_mt=b&hsa_net=adwords&hsa_ver=3&utm_term=Brand_Search&utm_campaign=ADYG_Search_Prospect_India_New&utm_source=ppc&utm_medium=Search&utm_content=India&hsa_acc=6269695156&hsa_cam=10147104471&hsa_grp=121864727666&hsa_ad=693458301313&hsa_src=g&hsa_tgt=kwd-371642833159&hsa_kw=adyogi&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gad_source=1&gclid=CjwKCAjw9eO3BhBNEiwAoc0-jdLHNQo6IdHcata6W8cv177JyG8DZJ6rHEA3yCsDlSPx7MhckzhbxBoCyyUQAvD_BwE",headers=headers).text

# %%
web_scrap=BeautifulSoup(webpage,'lxml')

# %%
print(web_scrap.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Adyogi - Scale Your ECommerce Ads Profitably
#   </title>
#   <link href="https://www.adyogi.com/hubfs/Adyogi_logo-01-1024x219%20(1)-1.png" rel="shortcut icon"/>
#   <meta content="" name="description"/>
#   <script crossorigin="anonymous" src="https://kit.fontawesome.com/28ff89e269.js">
#   </script>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script src="/hs/hsstatic/jquery-libs/static-1.1/jquery/jquery-1.7.1.js">
#   </script>
#   <script>
#    hsjQuery = window['jQuery'];
#   </script>
#   <meta content="" property="og:description"/>
#   <meta content="Adyogi - Scale Your ECommerce Ads Profitably" property="og:title"/>
#   <meta content="" name="twitter:description"/>
#   <meta content="Adyogi - Scale Your ECommerce Ads Profitably" name="twitter:title"/>
#   <style>
# ...

# %%
web_scrap.find_all('h1')[0].text
# Out:
# 'Scale eCommerce'

# %%
len(web_scrap.find_all('h2'))
# Out:
# 3

# %%
for i in web_scrap.find_all('h2'):
    print(i.text.strip())
# Out:
# Trusted by 350+ eCommerce brands globally
# Who is it for?
# Curious About How Adyogi’s Automations And Performance-Enhancing Features Can Help You Grow?

# %%
for i in web_scrap.find_all('span'):
    print(i.text.strip())
# Out:
# eCommerce
# Understand how Adyogi can help you automate your digital ads to get more conversions/sales with minimum effort and cost.
# better ROAS with Smart Ads v/s Normal Ads
# Ad budget saved on non-performing products
# Ad spends managed and distributed
# catalog size managed
# Marketplace vendors and retailers can use Adyogi to rank higher and reduce ACOS
# Established fast-growing brands with Omnichannel presence across geographies
# Schedule A Call
#
# Curious About How Adyogi’s Automations And Performance-Enhancing Features Can Help You Grow?
# Book a FREE personalized demo call today and welcome product-led growth!
#
#
#
# Help centre
# About us
# Terms and conditions
# Privacy Policy
# Terms and Condtions
# Privacy Policy

# %%
web_scrap.find_all('span', class_='companyCardWrapper__companyRatingValue')
# Out:
# []

# %%
len(web_scrap.find_all('span', class_='companyCardWrapper__companyRatingValue'))
# Out:
# 0

# %%
len(web_scrap.find_all('a'))
# Out:
# 15

# %%
for i in web_scrap.find_all('a'):
    print(i.text.strip())
# Out:
# Schedule Call
# Fashion
# Beauty
# Homeware
# Footwear
#
#
# Help centre
# About us
# Terms and conditions
# Privacy Policy
# Terms and Condtions
# Privacy Policy
# Back to top

# %%
web_scrap.find_all('span',class_='companyCardWrapper__ActionCount')
# Out:
# []

# %%
len(web_scrap.find_all('span',class_='companyCardWrapper__ActionCount'))
# Out:
# 0

# %%
from datasets import load_dataset

ds = load_dataset("RafaM97/marketing_social_media")

# %%
 ! pip install datasets
# Out:
# ...
#   WARNING: Failed to remove contents in a temporary directory 'D:\anaconda\Lib\site-packages\~yarrow'.
#   You can safely remove it manually.
# ...
#   Using cached pyarrow-17.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# ...
#    ---------------------------------------- 0.0/472.7 kB ? eta -:--:--
#     --------------------------------------- 10.2/472.7 kB ? eta -:--:--
#    --- ----------------------------------- 41.0/472.7 kB 487.6 kB/s eta 0:00:01
#    ----- --------------------------------- 71.7/472.7 kB 558.5 kB/s eta 0:00:01
#    ----------- -------------------------- 143.4/472.7 kB 774.0 kB/s eta 0:00:01
#    ------------------- -------------------- 225.3/472.7 kB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 317.4/472.7 kB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 440.3/472.7 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 472.7/472.7 kB 1.3 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade pyarrow

# %%
# !pip uninstall pyarrow
# !pip install pyarrow
